# %%
test

# %%
from huggingface_hub import list_repo_files

files = list_repo_files("nvidia/Cosmos-Predict2.5-2B")
# check if tokenizer.pth is in the list of files
if "tokenizer.pth" in files:
    print("tokenizer.pth is in the repository")
else:    print("tokenizer.pth is NOT in the repository")
# Out:
# tokenizer.pth is in the repository

# %%
from huggingface_hub import hf_hub_download

# Config from your checkpoint
repo_id = "nvidia/Cosmos-Predict2.5-2B"
revision = "f176dc95b4a70f53ce01c4b302851595e7322b00"
filename = "tokenizer.pth"

# Download file
local_path = hf_hub_download(
    repo_id=repo_id,
    filename=filename,
    revision=revision,
    local_dir_use_symlinks=False,
    local_dir="./checkpoints",
)

# %%
from huggingface_hub import HfApi
api = HfApi()
api.list_repo_refs("nvidia/Cosmos-Predict2.5-2B")
# Out:
# GitRefs(branches=[GitRefInfo(name='main', ref='refs/heads/main', target_commit='f176dc95b4a70f53ce01c4b302851595e7322b00'), GitRefInfo(name='diffusers/base/post-trained', ref='refs/heads/diffusers/base/post-trained', target_commit='0d37c7498f54cee3c599d438d895a0a4a8608064'), GitRefInfo(name='diffusers/base/pre-trained', ref='refs/heads/diffusers/base/pre-trained', target_commit='04dff8fb1184733bfcc8cebac659cdcf1b41c17f')], converts=[], tags=[], pull_requests=None)
