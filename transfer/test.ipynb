# %%
import torch

# %%
from datasets import load_dataset

ds = load_dataset("nvidia/PhysicalAI-Robotics-Open-H-Embodiment")
# Out:
# Using the latest cached version of the dataset since nvidia/PhysicalAI-Robotics-Open-H-Embodiment couldn't be found on the Hugging Face Hub (offline mode is enabled).
# Found the latest cached dataset configuration 'default' at /leonardo_scratch/large/userexternal/mnunzian/HF_DOWNLOADS/datasets/nvidia___physical_ai-robotics-open-h-embodiment/default/0.0.0/98d3cab0fed13a50b1239a75070383980ae3aa5f (last modified on Tue May 26 10:26:25 2026).

# %%
# Out:
# {'video': Video(decode=True, stream_index=None, dimension_order='NCHW', num_ffmpeg_threads=1, device='cpu', seek_mode='exact'),
#  'label': ClassLabel(names=['observation.images.endoscope.left', 'observation.images.endoscope.right', 'observation.images.wrist.left', 'observation.images.wrist.right'])}
